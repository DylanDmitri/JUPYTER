# %%
s = '''
46
63
21
115
125
35
89
17
116
90
51
66
111
142
148
60
2
50
82
20
47
24
80
101
103
16
34
72
145
141
124
14
123
27
62
61
95
138
29
7
149
147
104
152
22
81
11
96
97
30
41
98
59
45
88
37
10
114
110
4
56
122
139
117
108
91
36
146
131
109
31
75
70
140
38
121
3
28
118
54
107
84
15
76
71
102
130
132
87
55
129
83
23
42
69
1
77
135
128
94
'''

s = tuple(map(int, s.strip().split()))
s
# Out:
# (46,
#  63,
#  21,
#  115,
#  125,
#  35,
#  89,
#  17,
#  116,
#  90,
#  51,
#  66,
#  111,
#  142,
#  148,
#  60,
#  2,
#  50,
#  82,
#  20,
#  47,
#  24,
#  80,
#  101,
#  103,
#  16,
#  34,
#  72,
#  145,
#  141,
#  124,
#  14,
#  123,
#  27,
#  62,
#  61,
#  95,
#  138,
#  29,
#  7,
#  149,
#  147,
#  104,
#  152,
#  22,
#  81,
#  11,
#  96,
#  97,
#  30,
#  41,
#  98,
#  59,
#  45,
#  88,
#  37,
#  10,
#  114,
#  110,
#  4,
#  56,
#  122,
#  139,
#  117,
#  108,
#  91,
#  36,
#  146,
#  131,
#  109,
#  31,
#  75,
#  70,
#  140,
#  38,
#  121,
#  3,
#  28,
#  118,
#  54,
#  107,
#  84,
#  15,
#  76,
#  71,
#  102,
#  130,
#  132,
#  87,
#  55,
#  129,
#  83,
#  23,
#  42,
#  69,
#  1,
#  77,
#  135,
#  128,
#  94)

# %%
s = sorted(s)
s = [0] + s + [s[-1]+3]

print(s)

diffs = [s[i]-s[i-1] for i in range(1, len(s))]
print(diffs)
diffs.count(1) * diffs.count(3)
# Out:
# [0, 1, 2, 3, 4, 7, 10, 11, 14, 15, 16, 17, 20, 21, 22, 23, 24, 27, 28, 29, 30, 31, 34, 35, 36, 37, 38, 41, 42, 45, 46, 47, 50, 51, 54, 55, 56, 59, 60, 61, 62, 63, 66, 69, 70, 71, 72, 75, 76, 77, 80, 81, 82, 83, 84, 87, 88, 89, 90, 91, 94, 95, 96, 97, 98, 101, 102, 103, 104, 107, 108, 109, 110, 111, 114, 115, 116, 117, 118, 121, 122, 123, 124, 125, 128, 129, 130, 131, 132, 135, 138, 139, 140, 141, 142, 145, 146, 147, 148, 149, 152, 155]
# [1, 1, 1, 1, 3, 3, 1, 3, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 3, 1, 1, 3, 1, 3, 1, 1, 3, 1, 1, 1, 1, 3, 3, 1, 1, 1, 3, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 3, 1, 1, 1, 1, 3, 1, 1, 1, 1, 3, 3]
# 1998

# %%
diffs
# Out:
# [1,
#  1,
#  1,
#  3,
#  3,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  3,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3,
#  1,
#  1,
#  1,
#  1,
#  3]
